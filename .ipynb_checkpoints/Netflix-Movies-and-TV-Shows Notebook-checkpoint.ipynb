# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data = pd.read_csv("netflix_titles.csv")

# %%
data.groupby('release_year').count().show_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ffcd0393d2dd> in <module>
# ----> 1 data.groupby('release_year').count().show_id.columns
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
plt.hist(x=data.release_year.value_counts().index,y=data.release_year.value_counts())
# Out:
# (array([ 1.,  2.,  4.,  7., 10.,  9., 10.,  9., 10., 10.]),
#  array([1925. , 1934.5, 1944. , 1953.5, 1963. , 1972.5, 1982. , 1991.5,
#         2001. , 2010.5, 2020. ]),
#  <a list of 10 Patch objects>)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001DE9A0C47B8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# ...

# %%
data.release_year.value_counts().index
# Out:
# Int64Index([2018, 2017, 2019, 2016, 2015, 2014, 2013, 2012, 2010, 2011, 2009,
#             2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1997, 1998,
#             2020, 1999, 1993, 1995, 1996, 1992, 1990, 1991, 1994, 1988, 1989,
#             1982, 1986, 1973, 1983, 1974, 1985, 1984, 1980, 1981, 1978, 1979,
#             1976, 1987, 1975, 1977, 1968, 1972, 1960, 1945, 1946, 1943, 1962,
#             1971, 1967, 1944, 1958, 1965, 1942, 1969, 1954, 1966, 1970, 1947,
#             1955, 1959, 1963, 1964, 1956, 1925],
#            dtype='int64')

# %%
plt.hist(x=[1,2],bins=2,data=[10,23])
# Out:
# (array([1., 1.]), array([1. , 1.5, 2. ]), <a list of 2 Patch objects>)
